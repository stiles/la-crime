# %% [markdown]
# # LA Crime: Database models

# %% [markdown]
# #### Load Python tools and Jupyter config

# %%
import os
import json
import requests
import pandas as pd
import jupyter_black
from sodapy import Socrata

# %%
jupyter_black.load()
pd.options.display.max_columns = 100
pd.options.display.max_rows = 1000
pd.options.display.max_colwidth = None
# Out:
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>

# %%
today = pd.Timestamp("today").strftime("%Y%m%d")
today_epoch = int(pd.Timestamp.today().timestamp())

# %% [markdown]
# ---

# %% [markdown]
# ## Read

# %%
df = pd.read_parquet("../data/processed/incidents_df.parquet")
df[["premis_cd_id", "weapon_used_cd_id"]].isna().value_counts()
# Out:
# premis_cd_id  weapon_used_cd_id
# False         True                 1940479
#               False                 999336
# True          True                     494
#               False                    248
# Name: count, dtype: int64

# %%
df.head()
# Out:
#        dr_no date_rptd date_occ  time_occ  area_name rpt_dist_no part_1_2  \
# 0  001307355      None     None  13:50:00     Newton        1385        2
# 1  011401303      None     None  00:45:00    Pacific        1485        2
# 2  070309629      None     None  15:15:00     Newton        1324        2
# 3  090631215      None     None  01:50:00  Hollywood        0646        2
# 4  100100501      None     None  21:00:00    Central        0176        1
#
#                                                crm_cd_desc         mocodes  \
# 0                                 VIOLATION OF COURT ORDER  0913 1814 2000
# 1  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)            0329
# 2                                OTHER MISCELLANEOUS CRIME            0344
# 3                                 VIOLATION OF COURT ORDER  1100 0400 1402
# 4                                          RAPE, ATTEMPTED            0400
#
#   vict_age vict_descent             premis_desc  \
# 0       48            H  SINGLE FAMILY DWELLING
# 1        0            W                  STREET
# 2        0            H                   ALLEY
# 3       47            W                  STREET
# 4       47            H                   ALLEY
#
#                                       weapon_desc   status_desc crm_cd_1  \
# 0                                             nan  Adult Arrest      900
# 1                                             nan   Invest Cont      740
# 2                                             nan   Invest Cont      946
# 3                                        HAND GUN   Invest Cont      900
# 4  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)   Invest Cont      122
#
#   crm_cd_2 crm_cd_3 crm_cd_4                                 location  \
# 0      nan      nan      nan   300 E  GAGE                         AV
# 1      nan      nan      nan          SEPULVEDA                    BL
# 2      nan      nan      nan  1300 E  21ST                         ST
# 3      998      nan      nan          CAHUENGA                     BL
# 4      nan      nan      nan          8TH                          ST
#
#                       cross_street      lat       lon datetime_occurred  \
# 0                              nan  33.9825 -118.2695              None
# 1  MANCHESTER                   AV  33.9599 -118.3962              None
# 2                              nan  34.0224 -118.2524              None
# 3  HOLLYWOOD                    BL  34.1016 -118.3295              None
# 4  SAN PEDRO                    ST  34.0387 -118.2488              None
#
#    area_id  crm_cd_id  premis_cd_id  weapon_used_cd_id  status_id  vict_sex_id
# 0        1          1           1.0                NaN          1            1
# 1        2          2           2.0                NaN          2            1
# 2        1          3           3.0                NaN          2            1
# 3        3          1           2.0                1.0          2            2
# 4        4          4           3.0                2.0          2            2
